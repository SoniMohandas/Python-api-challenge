# %% [markdown]
# # Three main observations of weather analysis:
#
# 1st Observation: The latitude vs. maximum temperature regression plot analysis reveals (07/13/21) that towards the equator (towards zero degree latitude), maximum temperature at the cities are higher compared to higher or lower latitudes.  Which means, latitude is one of the reasons of higher temperature at a place.
#
# 2nd Observation: The latitude vs. cloudiness regression plot analysis (07/13/21) reveals that at northern hemisphere cloudiness evenly poised along the latitude but at southern hemisphere cloudiness is higher than towards lower latitudes.
#
# 3rd Observation: The latitude vs. wind speed regression plot analysis (07/13/21) reveals that at lower latitudes (southern hemisphere) wind speed is little bit higher than towards the equator but at higher latitudes (northern hemisphere) wind speed is almost same means evenly poised all along the latitudes.

# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
import json
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy

# Openweathermap API key
from api_keys import weather_api_key

# %% [markdown]
# ## Generate Cities List

# %%
# Creating a list for cities
cities=[]

# Longitude, latitude combinations and then values within the given range is 
# equally likely drawn by uniform
lat = np.random.uniform(-90, 90, 1500)
lon = np.random.uniform(-180, 180, 1500)

# zip funtion is used to iterating in pair of latitudes and longitues.
lats_lons = zip(lat, lon)

# Finding nearest city for each latitue and longitude in pair
for lt_lo in lats_lons:
    city = citipy.nearest_city(lt_lo[0], lt_lo[1]).city_name
    
    # Finding unique city, then adding to cities list
    if city not in cities:
        cities.append(city)
    
# Print the city count
len(cities)
# Out:
# 621

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base url for the weather records
base_url="http://api.openweathermap.org/data/2.5/weather?"
units="Imperial"

# Query url for the weather records
query_url = f"{base_url}&appid={weather_api_key}&units={units}&q="

# Lists is created
city_name=[]
lat=[]
lon=[]
max_temp=[]
humidity=[]
cloudiness=[]
wind_speed=[]
country_name=[]
date=[]

print("Beginning Data Retrieval")
print("-------------------------------")

# City count and set count
city_count=1
set_count = 1

# for loop for each city response from json()
for city in cities:
    response = requests.get(query_url + city).json()
    
    try:
        city_name.append(response['name'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country_name.append(response['sys']['country'])
        date.append(response['dt'])
        
        print(f"Processing Record {city_count} of Set {set_count} | {city}")
        city_count=city_count + 1
        if city_count > 50:
            city_count=1
            set_count+=1
    except:
        print("City not found. Skipping...")
        pass
    
print("---------------------------")
print("Data Retrieval Complete")
print("---------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | coihaique
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | ngerengere
# Processing Record 5 of Set 1 | baft
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | xining
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | mitsamiouli
# Processing Record 10 of Set 1 | labuhan
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | pisco
# Processing Record 16 of Set 1 | reading
# Processing Record 17 of Set 1 | tindivanam
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | kaitangata
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | ancud
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | igarka
# Processing Record 26 of Set 1 | dingle
# Processing Record 27 of Set 1 | gardelegen
# Processing Record 28 of Set 1 | elizabethtown
# Processing Record 29 of Set 1 | quirinopolis
# Processing Record 25 of Set 4 | korhogo
# Processing Record 26 of Set 4 | hasaki
# Processing Record 27 of Set 4 | kahului
# Processing Record 28 of Set 4 | inirida
# Processing Record 29 of Set 4 | iranshahr
# Processing Record 30 of Set 4 | krasnyy chikoy
# Processing Record 31 of Set 4 | adrar
# Processing Record 32 of Set 4 | demba
# Processing Record 33 of Set 4 | egvekinot
# City not found. Skipping...
# Processing Record 34 of Set 4 | constitucion
# City not found. Skipping...
# Processing Record 35 of Set 4 | zhaotong
# Processing Record 36 of Set 4 | kolyvan
# Processing Record 37 of Set 4 | tilichiki
# Processing Record 38 of Set 4 | saint george
# Processing Record 39 of Set 4 | torbay
# Processing Record 40 of Set 4 | kaka
# Processing Record 41 of Set 4 | axim
# Processing Record 42 of Set 4 | codrington
# Processing Record 43 of Set 4 | pundaguitan
# Processing Record 44 of Set 4 | port alfred
# Processing Record 45 of Set 4 | te anau
# Processing Record 46 of Set 4 | ossora
# Processing Record 47 of Set 4 | bengkulu
# Processing Record 48 of Set 4 | wageningen
# Processing Record 49 of Set 4 | jalingo
# Processing Record 50 of Set 4 | kamenka
# Processing Record 1 of Set 5 | thika
# Processing Record 2 of Set 5 | lazaro cardenas
# Processing Record 3 of Set 5 | souillac
# Processing Record 4 of Set 5 | hailey
# Processing Record 5 of Set 5 | ilhabela
# Processing Record 6 of Set 5 | harper
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 5 | tuatapere
# City not found. Skipping...
# Processing Record 8 of Set 5 | kenai
# Processing Record 9 of Set 5 | avarua
# Processing Record 10 of Set 5 | tiznit
# Processing Record 11 of Set 5 | hailar
# Processing Record 12 of Set 5 | dalhousie
# Processing Record 13 of Set 5 | poronaysk
# Processing Record 14 of Set 5 | qinhuangdao
# Processing Record 15 of Set 5 | santo antonio do ica
# Processing Record 16 of Set 5 | el rosario
# Processing Record 17 of Set 5 | cidreira
# Processing Record 18 of Set 5 | am timan
# Processing Record 19 of Set 5 | ada
# Processing Record 20 of Set 5 | jieshi
# Processing Record 21 of Set 5 | mount pleasant
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of Set 5 | alofi
# City not found. Skipping...
# Processing Record 23 of Set 5 | cabo san lucas
# Processing Record 24 of Set 5 | kodiak
# Processing Record 25 of Set 5 | arroyo
# Processing Record 26 of Set 5 | namibe
# Processing Record 27 of Set 5 | cockburn town
# Processing Record 28 of Set 5 | port macquarie
# Processing Record 29 of Set 5 | vanavara
# Processing Record 30 of Set 5 | zhireken
# Processing Record 31 of Set 5 | pontiac
# Processing Record 32 of Set 5 | katsuura
# City not found. Skipping...
# Processing Record 33 of Set 5 | ayan
# Processing Record 34 of Set 5 | port lincoln
# City not found. Skipping...
# Processing Record 35 of Set 5 | emerald
# Processing Record 36 of Set 5 | mubi
# Processing Record 37 of Set 5 | zemio
# Processing Record 38 of Set 5 | ulaangom
# Processing Record 39 of Set 5 | leningradskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | inhambane
# Processing Record 41 of Set 5 | krasnoselkup
# Processing Record 42 of Set 5 | villefranche-de-rouergue
# Processing Record 43 of Set 5 | faanui
# Processing Record 44 of Set 5 | katherine
# Processing Record 45 of Set 5 | skibbereen
# Processing Record 46 of Set 5 | weatherford
# Processing Record 47 of Set 5 | forio
# Processing Record 48 of Set 5 | kruisfontein
# Processing Record 49 of Set 5 | boende
# Processing Record 50 of Set 5 | langarud
# Processing Record 1 of Set 6 | atambua
# Processing Record 2 of Set 6 | ronneby
# Processing Record 3 of Set 6 | carman
# Processing Record 4 of Set 6 | marsa matruh
# City not found. Skipping...
# Processing Record 5 of Set 6 | seoul
# Processing Record 6 of Set 6 | charters towers
# Processing Record 7 of Set 6 | denpasar
# Processing Record 8 of Set 6 | atar
# Processing Record 9 of Set 6 | oriximina
# Processing Record 10 of Set 6 | katete
# Processing Record 11 of Set 6 | san buenaventura
# Processing Record 12 of Set 6 | kachug
# Processing Record 13 of Set 6 | nouadhibou
# Processing Record 14 of Set 6 | paamiut
# Processing Record 15 of Set 6 | prince rupert
# City not found. Skipping...
# Processing Record 16 of Set 6 | poum
# City not found. Skipping...
# Processing Record 17 of Set 6 | ouango
# Processing Record 18 of Set 6 | lompoc
# Processing Record 19 of Set 6 | sur
# Processing Record 20 of Set 6 | berlevag
# Processing Record 21 of Set 6 | antofagasta
# Processing Record 22 of Set 6 | zonguldak
# Processing Record 23 of Set 6 | santa cruz
# Processing Record 24 of Set 6 | viedma
# Processing Record 25 of Set 6 | san jeronimo
# Processing Record 26 of Set 6 | volksrust
# Processing Record 27 of Set 6 | deputatskiy
# Processing Record 28 of Set 6 | lucapa
# City not found. Skipping...
# Processing Record 29 of Set 6 | sivas
# Processing Record 30 of Set 6 | kiruna
# Processing Record 31 of Set 6 | jawhar
# Processing Record 32 of Set 6 | vitim
# City not found. Skipping...
# Processing Record 33 of Set 6 | batagay
# Processing Record 34 of Set 6 | palmerston
# Processing Record 35 of Set 6 | batagay-alyta
# Processing Record 36 of Set 6 | kununurra
# City not found. Skipping...
# Processing Record 37 of Set 6 | basco
# Processing Record 38 of Set 6 | spornoye
# Processing Record 39 of Set 6 | mecca
# Processing Record 40 of Set 6 | bulawayo
# Processing Record 41 of Set 6 | puga
# Processing Record 42 of Set 6 | tateyama
# Processing Record 43 of Set 6 | san blas
# Processing Record 44 of Set 6 | mehran
# Processing Record 45 of Set 6 | vila
# Processing Record 46 of Set 6 | tra vinh
# Processing Record 47 of Set 6 | puerto del rosario
# City not found. Skipping...
# Processing Record 48 of Set 6 | ilovlya
# Processing Record 49 of Set 6 | manuk mangkaw
# Processing Record 50 of Set 6 | port hardy
# Processing Record 1 of Set 7 | dwarka
# City not found. Skipping...
# Processing Record 2 of Set 7 | severo-kurilsk
# Processing Record 3 of Set 7 | ulladulla
# City not found. Skipping...
# Processing Record 4 of Set 7 | tulun
# Processing Record 5 of Set 7 | bonavista
# City not found. Skipping...
# Processing Record 6 of Set 7 | beruwala
# Processing Record 7 of Set 7 | ketchikan
# City not found. Skipping...
# Processing Record 8 of Set 7 | pevek
# Processing Record 9 of Set 7 | alice springs
# Processing Record 10 of Set 7 | kingaroy
# Processing Record 11 of Set 7 | srednekolymsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# Processing Record 7 of Set 10 | makakilo city
# Processing Record 8 of Set 10 | kinchil
# Processing Record 9 of Set 10 | reconquista
# Processing Record 10 of Set 10 | scarborough
# Processing Record 11 of Set 10 | liverpool
# Processing Record 12 of Set 10 | denia
# Processing Record 13 of Set 10 | avera
# Processing Record 14 of Set 10 | lampazos de naranjo
# Processing Record 15 of Set 10 | flinders
# Processing Record 16 of Set 10 | tual
# Processing Record 17 of Set 10 | alihe
# Processing Record 18 of Set 10 | ariquemes
# Processing Record 19 of Set 10 | tura
# City not found. Skipping...
# Processing Record 20 of Set 10 | rio gallegos
# Processing Record 21 of Set 10 | laguna de perlas
# Processing Record 22 of Set 10 | salinopolis
# Processing Record 23 of Set 10 | valparaiso
# Processing Record 24 of Set 10 | rayong
# Processing Record 25 of Set 10 | sidi ali
# Processing Record 26 of Set 10 | severnoye
# Processing Record 27 of Set 10 | mount isa
# Processing Record 28 of Set 10 | wasilla
# Processing Record 29 of Set 10 | kastamonu
# Processing Record 30 of Set 10 | bose
# Processing Record 31 of Set 10 | tessalit
# Processing Record 32 of Set 10 | lopsmarka
# Processing Record 33 of Set 10 | alghero
# Processing Record 34 of Set 10 | progreso
# Processing Record 35 of Set 10 | anjiang
# Processing Record 36 of Set 10 | kaniama
# Processing Record 37 of Set 10 | tromso
# Processing Record 38 of Set 10 | george
# Processing Record 39 of Set 10 | outjo
# Processing Record 40 of Set 10 | serpa
# Processing Record 41 of Set 10 | kamina
# City not found. Skipping...
# Processing Record 42 of Set 10 | cedar rapids
# Processing Record 43 of Set 10 | bria
# Processing Record 44 of Set 10 | pemangkat
# Processing Record 45 of Set 10 | ucluelet
# Processing Record 46 of Set 10 | mendi
# Processing Record 47 of Set 10 | banda aceh
# Processing Record 48 of Set 10 | tianmen
# Processing Record 49 of Set 10 | cruces
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 10 | coquimbo
# Processing Record 1 of Set 11 | amapa
# Processing Record 2 of Set 11 | nanortalik
# Processing Record 3 of Set 11 | vigrestad
# Processing Record 4 of Set 11 | boundiali
# City not found. Skipping...
# Processing Record 5 of Set 11 | vestmannaeyjar
# Processing Record 6 of Set 11 | bukama
# Processing Record 7 of Set 11 | pak phanang
# Processing Record 8 of Set 11 | tongliao
# Processing Record 9 of Set 11 | yerbogachen
# Processing Record 10 of Set 11 | half moon bay
# Processing Record 11 of Set 11 | sinnamary
# Processing Record 12 of Set 11 | bonthe
# Processing Record 13 of Set 11 | hatillo
# Processing Record 14 of Set 11 | kysyl-syr
# Processing Record 15 of Set 11 | kanniyakumari
# Processing Record 16 of Set 11 | kristiinankaupunki
# Processing Record 17 of Set 11 | tuscaloosa
# Processing Record 18 of Set 11 | nhulunbuy
# Processing Record 19 of Set 11 | belmonte
# Processing Record 20 of Set 11 | pringsewu
# Processing Record 21 of Set 11 | gao
# Processing Record 22 of Set 11 | sao lourenco
# Processing Record 23 of Set 11 | cacequi
# Processing Record 24 of Set 11 | catalao
# Processing Record 25 of Set 11 | husavik
# Processing Record 26 of Set 11 | krasnaya yaruga
# Processing Record 27 of Set 11 | faya
# Processing Record 28 of Set 11 | golden gate
# Processing Record 29 of Set 11 | baykit
# Processing Record 30 of Set 11 | udachnyy
# Processing Record 31 of Set 11 | isangel
# Processing Record 32 of Set 11 | jauharabad
# Processing Record 33 of Set 11 | matara
# Processing Record 34 of Set 11 | puerto suarez
# Processing Record 35 of Set 11 | la rioja
# Processing Record 36 of Set 11 | jiuquan
# City not found. Skipping...
# Processing Record 37 of Set 11 | chimbote
# Processing Record 38 of Set 11 | blind river
# City not found. Skipping...
# Processing Record 39 of Set 11 | butia
# Processing Record 40 of Set 11 | komsomolskiy
# City not found. Skipping...
# Processing Record 41 of Set 11 | itoigawa
# City not found. Skipping...
# Processing Record 42 of Set 11 | yaan
# Processing Record 43 of Set 11 | miles city
# Processing Record 44 of Set 11 | okhtyrka
# Processing Record 45 of Set 11 | zhezkazgan
# Processing Record 46 of Set 11 | chernyshevsk
# Processing Record 47 of Set 11 | kasempa
# Processing Record 48 of Set 11 | senanga
# Processing Record 49 of Set 11 | saint-joseph
# Processing Record 50 of Set 11 | orange cove
# Processing Record 1 of Set 12 | mikhaylovka
# Processing Record 2 of Set 12 | richards bay
# Processing Record 3 of Set 12 | buin
# Processing Record 4 of Set 12 | eyl
# Processing Record 5 of Set 12 | geilo
# Processing Record 6 of Set 12 | biryusinsk
# Processing Record 7 of Set 12 | havelock
# Processing Record 8 of Set 12 | juneau
# Processing Record 9 of Set 12 | puerto madero
# Processing Record 10 of Set 12 | hokitika
# Processing Record 11 of Set 12 | coihueco
# Processing Record 12 of Set 12 | melipilla
# Processing Record 13 of Set 12 | comodoro rivadavia
# Processing Record 14 of Set 12 | zhigansk
# Processing Record 15 of Set 12 | woodward
# Processing Record 16 of Set 12 | honiara
# Processing Record 17 of Set 12 | bayir
# Processing Record 18 of Set 12 | mandeville
# ---------------------------
# Data Retrieval Complete
# ---------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Creating a dataframe
weather_report={"City":city_name, "Country":country_name, "Latitude":lat, "Longitude":lon, "Max Temperature":max_temp,"Humidity":humidity,
                         "Cloudiness": cloudiness, "Wind Speed": wind_speed, "Date":date}
weather_df=pd.DataFrame(weather_report) 

# Finding the number of cities with weather report
print(f"Total number of cities with weather report {len(weather_df.index)}")
weather_df.head()
# Out:
# Total number of cities with weather report 568
#            City Country  Latitude  Longitude  Max Temperature  Humidity  \
# 0     Coyhaique      CL  -45.5752   -72.0662            38.34        99
# 1  Punta Arenas      CL  -53.1500   -70.9167            26.71        93
# 2     Busselton      AU  -33.6500   115.3333            57.04        67
# 3    Ngerengere      TZ   -6.7500    38.1167            67.75        95
# 4          Baft      IR   29.2340    56.6057            77.63        33
#
#    Cloudiness  Wind Speed        Date
# 0         100        3.67  1626230190
# 1          75        3.44  1626229916
# 2          49       18.25  1626230190
# 3          51        1.66  1626230191
# 4          11        2.66  1626230191

# %%
# Exporting csv file to Output folder
weather_df.to_csv(r'Output\city_weather.csv')

# %%
# Finding the aggregate values of all the numeric columns in the dataframe
agg_weather_summary=weather_df.agg('describe')
agg_weather_summary
# Out:
#          Latitude   Longitude  Max Temperature    Humidity  Cloudiness  \
# count  568.000000  568.000000       568.000000  568.000000  568.000000
# mean    19.697713   18.231331        68.893451   71.658451   56.614437
# std     33.688566   90.650682        13.711213   19.019517   38.943829
# min    -54.800000 -179.166700        26.600000    8.000000    0.000000
# 25%     -8.944675  -61.940275        59.477500   60.000000   16.750000
# 50%     22.834600   21.076800        70.555000   75.000000   68.000000
# 75%     49.158525  102.334775        79.472500   87.000000   97.000000
# max     78.218600  179.316700       104.050000  100.000000  100.000000
#
#        Wind Speed          Date
# count  568.000000  5.680000e+02
# mean     7.756373  1.626230e+09
# std      5.561208  7.309820e+01
# min      0.000000  1.626230e+09
# 25%      3.440000  1.626230e+09
# 50%      6.620000  1.626230e+09
# 75%     10.985000  1.626230e+09
# max     30.740000  1.626230e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_gt_hundred=weather_df.loc[weather_df['Humidity'] > 100]

humidity_gt_hundred.Humidity.count()
# Out:
# 0

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
font1 = {'family':'serif','color':'darkgreen','size':15}
font2 = {'family':'serif','color':'darkred','size':15}

# Scatter plot Maximum Temperature Vs. Latitude
plt.scatter(weather_df.iloc[:,2], weather_df.iloc[:, 4], marker='o', 
            edgecolor='black', s=50, alpha=0.75, c ='c', label="Avg Tumor Volume")

# Style formatting title and labels
plt.title("City Latitude vs. Max Temperature (07/13/21)", fontdict=font1)
plt.xlabel('Latitude', fontdict=font2)
plt.ylabel('Max Temperature (F)', fontdict=font2)
plt.grid()

# Exporting png files to the folder PNG
plt.savefig('PNG\lat_temp.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Scatter plot Humidity (%) Vs. Latitude
plt.scatter(weather_df.iloc[:,2], weather_df.iloc[:, 5], marker='o', 
            edgecolor='black', s=50, alpha=0.75, c ='y', label="Avg Tumor Volume")

# Style formatting title and labels
plt.title("City Latitude vs. Humidity (07/13/21)", fontdict=font1)
plt.xlabel('Latitude', fontdict=font2)
plt.ylabel('Humidity (%)', fontdict=font2)
plt.grid()

# Exporting png files to the folder PNG
plt.savefig('PNG\lat_humid.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Scatter plot Cloudiness (%) vs. Latitude
plt.scatter(weather_df.iloc[:,2], weather_df.iloc[:, 6], marker='o', 
            edgecolor='black', s=50, alpha=0.75, c ='m', label="Avg Tumor Volume")

# Style formatting title and labels
plt.title("City Latitude vs. Cloudiness (07/13/21)", fontdict=font1)
plt.xlabel('Latitude', fontdict=font2)
plt.ylabel('Cloudiness (%)', fontdict=font2)
plt.grid()

# Exporting png files to the folder PNG
plt.savefig('PNG\lat_cloud.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Scatter plot Wind Speed (mph) Vs. Latitude
plt.scatter(weather_df.iloc[:,2], weather_df.iloc[:, 7], marker='o', 
            edgecolor='black', s=50, alpha=0.75, c ='g', label="Avg Tumor Volume")

# Style formatting title and labels
plt.title("City Latitude vs. Wind Speed (07/13/21)", fontdict=font1)
plt.xlabel('Latitude', fontdict=font2)
plt.ylabel('Wind Speed (mph)',fontdict=font2)
plt.grid()

# Exporting png files to the folder PNG
plt.savefig('PNG\lat_wind_speed.png')

# %% [markdown]
# ## Linear Regression

# %%
# Dependencies importing
import scipy.stats as sts
from scipy.stats import linregress

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Northern hemisphere latitude positive values
northern_weather=weather_df.loc[weather_df.Latitude > 0]

# Extracting column values of latitude and max temperature
lat_north=northern_weather['Latitude']
temp_north=northern_weather['Max Temperature']

fig, ax = plt.subplots()

# Finding slope, intercept, rvalue, pvalue and standard error
(slope, intercept, rvalue, pvalue, stderr) = linregress(lat_north,temp_north)

# Calculating the regression value
regress_values = lat_north * slope + intercept

# Finding the line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Scatter plotting
plt.scatter(lat_north,temp_north, c='c', marker='*', s=90, edgecolor='black')

# Regression line plotting
plt.plot(lat_north,regress_values,"r-", label=line_eq)
plt.annotate(line_eq,(45,90),fontsize=15,color="red")

# Style formatting title and labels
plt.title("Max Temp vs. Latitude Linear Regression (07/12/21)", fontdict=font1)
plt.xlabel('Latitude', fontdict=font2)
plt.ylabel('Max Temperature (F))',fontdict=font2)

# Exporting png files to the folder PNG
plt.savefig('PNG\lat_temp_regr(N).png')

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Southern hemisphere latitude negative values
southern_weather=weather_df.loc[weather_df.Latitude < 0]

# Extracting column values of latitude and max temperature
lat_south=southern_weather['Latitude']
temp_south=southern_weather['Max Temperature']

fig, ax = plt.subplots()

# Finding slope, intercept, rvalue, pvalue and standard error
(slope, intercept, rvalue, pvalue, stderr) = linregress(lat_south,temp_south)

# Calculating the regression value
regress_values = lat_south * slope + intercept

# Finding the line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(lat_south,temp_south, c='c', marker='*', s=90, edgecolor='black')

plt.plot(lat_south,regress_values,"r-", label=line_eq)
plt.annotate(line_eq,(-55,70),fontsize=15,color="red")

# Style formatting title and labels
plt.title("Max Temp vs. Latitude Linear Regression (07/13/21)", fontdict=font1)
plt.xlabel('Latitude', fontdict=font2)
plt.ylabel('Max Temperature (F))',fontdict=font2)

# Exporting png files to the folder PNG
plt.savefig('PNG\lat_temp_regr(S).png')

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Extracting column values of Humidity from the dataframe northern_weather
humi_north=northern_weather['Humidity']

fig, ax = plt.subplots()

# Finding slope, intercept, rvalue, pvalue and standard error
(slope, intercept, rvalue, pvalue, stderr) = linregress(lat_north,humi_north)

# Calculating the regression value
regress_values = lat_north * slope + intercept

# Finding the line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Scatter ploting
plt.scatter(lat_north,humi_north, c='y', marker='*', s=90, edgecolor='black')

# Regression line plotting
plt.plot(lat_north,regress_values,"r-", label=line_eq)
plt.annotate(line_eq,(45,15),fontsize=15,color="red")

# Style formatting title and labels
plt.title("Humidity vs. Latitude Linear Regression (07/13/21)", fontdict=font1)
plt.xlabel('Latitude', fontdict=font2)
plt.ylabel('Humidity (%))',fontdict=font2)

# Exporting png files to the folder PNG
plt.savefig('PNG\lat_humid_regr(N).png')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Extracting column values of Humidity from the dataframe southern_weather
humi_south=southern_weather['Humidity']

fig, ax = plt.subplots()

# Finding slope, intercept, rvalue, pvalue and standard error
(slope, intercept, rvalue, pvalue, stderr) = linregress(lat_south,humi_south)

# Calculating the regression value
regress_values = lat_south * slope + intercept

# Finding the line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Scatter plotting
plt.scatter(lat_south,humi_south, c='y', marker='*', s=90, edgecolor='black')

# Regression line plotting
plt.plot(lat_south,regress_values,"r-", label=line_eq)
plt.annotate(line_eq,(-57,40),fontsize=15,color="red")

# Style formatting title and labels
plt.title("Humidity vs. Latitude Linear Regression (07/13/21)", fontdict=font1)
plt.xlabel('Latitude', fontdict=font2)
plt.ylabel('Humidity (%))',fontdict=font2)

# Exporting png files to the folder PNG
plt.savefig('PNG\lat_humid_regr(S).png')

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Extracting column values of cloudiness from the dataframe northern_weather
cloud_north=northern_weather['Cloudiness']

fig, ax = plt.subplots()

# Finding values of slope, intercept, rvalue, pvalue, stderr
(slope, intercept, rvalue, pvalue, stderr) = linregress(lat_north,cloud_north)

# Calculating the regression value
regress_values = lat_north * slope + intercept

# Finding the line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Scatter plotting
plt.scatter(lat_north,cloud_north, c='1', marker='*', s=90, edgecolor='black')

# Regression line plotting
plt.plot(lat_north,regress_values,"r-", label=line_eq)
plt.annotate(line_eq,(50,50),fontsize=15,color="red")

# Style formatting title and labels
plt.title("Cloudiness vs. Latitude Linear Regression (07/13/21)", fontdict=font1)
plt.xlabel('Latitude', fontdict=font2)
plt.ylabel('Cloudiness (%))',fontdict=font2)

# Exporting png files to the folder PNG
plt.savefig('PNG\lat_cloud_regr(N).png')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Extracting column values of cloudiness from the dataframe southern_weather
cloud_south=southern_weather['Cloudiness']

fig, ax = plt.subplots()

# Finding values of slope, intercept, rvalue, pvalue, stderr
(slope, intercept, rvalue, pvalue, stderr) = linregress(lat_south,cloud_south)

# Calculating the regression value
regress_values = lat_south * slope + intercept

# Finding the line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Scatter plotting
plt.scatter(lat_south,cloud_south, c='1', marker='*', s=90, edgecolor='black')

# Regression line plotting
plt.plot(lat_south,regress_values,"r-", label=line_eq)
plt.annotate(line_eq,(-57,60),fontsize=15,color="red")

# Style formatting title and labels
plt.title("Cloudiness vs. Latitude Linear Regression (07/13/21)", fontdict=font1)
plt.xlabel('Latitude', fontdict=font2)
plt.ylabel('Cloudiness (%))',fontdict=font2)

# Exporting png files to the folder PNG
plt.savefig('PNG\lat_cloud_regr(S).png')

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Extracting column values of wind speed from the dataframe northern_weather
wind_north=northern_weather['Wind Speed']

fig, ax = plt.subplots()

# Finding values of slope, intercept, rvalue, pvalue, stderr
(slope, intercept, rvalue, pvalue, stderr) = linregress(lat_north,wind_north)

# Calculating the regression value
regress_values = lat_north * slope + intercept

# Finding the line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Scatter plotting
plt.scatter(lat_north,wind_north, c='g', marker='o', s=70, edgecolor='black')

# Regression line plotting
plt.plot(lat_north,regress_values,"r-", label=line_eq)
plt.annotate(line_eq,(30,20),fontsize=15,color="red")

# Style formatting title and labels
plt.title("Wind Speed vs. Latitude Linear Regression (07/13/21)", fontdict=font1)
plt.xlabel('Latitude', fontdict=font2)
plt.ylabel('Wind Speed (mph))',fontdict=font2)

# Exporting png files to the folder PNG
plt.savefig('PNG\lat_wind_regr(N).png')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Extracting column values of wind speed from the dataframe southern_weather 
wind_south=southern_weather['Wind Speed']

fig, ax = plt.subplots()

# Finding values of slope, intercept, rvalue, pvalue, stderr
(slope, intercept, rvalue, pvalue, stderr) = linregress(lat_south,wind_south)

# Calculating the regression value
regress_values = lat_south * slope + intercept

# Finding the line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Scatter plotting
plt.scatter(lat_south,wind_south, c='c', marker='o', s=60, edgecolor='black')

# Regression line plotting
plt.plot(lat_south,regress_values,"r-", label=line_eq)
plt.annotate(line_eq,(-57,12),fontsize=15,color="red")

# Style formatting title and labels
plt.title("Wind Speed vs. Latitude Linear Regression (07/13/21)", fontdict=font1)
plt.xlabel('Latitude', fontdict=font2)
plt.ylabel('Wind Speed (mph))',fontdict=font2)

# Exporting png files to the folder PNG
plt.savefig('PNG\lat_wind_regr(S).png')
